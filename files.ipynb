# %%
a=1000

# %%
f=open("1.jpg")

# %%
f=open("11.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-12e599f28e53> in <module>()
# ----> 1 f=open("11.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '11.jpg'

# %%
pwd
# Out:
# '/home/khyaathipython/batch63'

# %%
path="data/customers.csv"
import os
print(os.path.join("data","customers.cav"))
# Out:
# data/customers.cav

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"w")

# %%
f.write("customer1,customer2,customer3,customer4")
# Out:
# 39

# %%
f.close() # f.flush()

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"w")

# %%
f.write("some data")
# Out:
# 9

# %%
f.close()

# %%
f.write("some more data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8e8e5ea8faef> in <module>()
# ----> 1 f.write("some more data")
#
# ValueError: I/O operation on closed file.

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"w")
f.write("some data")
f.flush()
f.write("some more data")
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"a")
f.write("123")
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
customers=["anil","jay","vedha","sai","dhana"]
f=open(path,"w")
f.write(customers)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-24e593c2b645> in <module>()
#       3 customers=["anil","jay","vedha","sai","dhana"]
#       4 f=open(path,"w")
# ----> 5 f.write(customers)
#       6 f.close()
#
# TypeError: write() argument must be str, not list

# %%
import os
path=os.path.join("data","customers.csv")
customers=["anil","jay","vedha","sai","dhana"]
f=open(path,"w")
f.writelines(customers)
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
customers=["anil\n","jay\n","vedha\n","sai\n","dhana\n"]
f=open(path,"w")
f.writelines(customers)
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
customers=["anil\n","jay\n","vedha\n","sai\n","dhana\n",12,34.56,78,1+2j,{"name":"1234"}]
f=open(path,"w")
f.writelines(customers)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b209121aa72a> in <module>()
#       3 customers=["anil\n","jay\n","vedha\n","sai\n","dhana\n",12,34.56,78,1+2j,{"name":"1234"}]
#       4 f=open(path,"w")
# ----> 5 f.writelines(customers)
#       6 f.close()
#
# TypeError: write() argument must be str, not int

# %%
import os
path=os.path.join("data","customers.csv")
customers= [{"name":"JAY","age":23,"address":"devendernagar"},{"name":"vedha","age":21,"address":"ameerpet"}]
f=open(path,"w")
f.write(customers)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8a4e0822431a> in <module>()
#       3 customers= [{"name":"JAY","age":23,"address":"devendernagar"},{"name":"vedha","age":21,"address":"ameerpet"}]
#       4 f=open(path,"w")
# ----> 5 f.write(customers)
#       6 f.close()
#
# TypeError: write() argument must be str, not list

# %%
import os
path=os.path.join("data","customers.csv")
customers= [{"name":"JAY","age":23,"address":"devendernagar"},{"name":"vedha","age":21,"address":"ameerpet"}]
f=open(path,"w")
f.writelines(customers)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-3b366294f49a> in <module>()
#       3 customers= [{"name":"JAY","age":23,"address":"devendernagar"},{"name":"vedha","age":21,"address":"ameerpet"}]
#       4 f=open(path,"w")
# ----> 5 f.writelines(customers)
#       6 f.close()
#
# TypeError: write() argument must be str, not dict

# %%
import os
path=os.path.join("data","customers.csv")
customers= [{"name":"JAY","age":23,"address":"devendernagar"},{"name":"vedha","age":21,"address":"ameerpet"}]
f=open(path,"w")
f.write(str(customers))
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"r")
data = f.read()
print(data)
print(type(data))
# Out:
# [{'name': 'JAY', 'age': 23, 'address': 'devendernagar'}, {'name': 'vedha', 'age': 21, 'address': 'ameerpet'}]
# <class 'str'>

# %%
import json

# %%
json.dumps(data)
# Out:
# '"[{\'name\': \'JAY\', \'age\': 23, \'address\': \'devendernagar\'}, {\'name\': \'vedha\', \'age\': 21, \'address\': \'ameerpet\'}]"'

# %%
json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-29-6ba32c76427f> in <module>()
# ----> 1 json.loads(data)
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"r")
data = f.read()
print(data)
data = data.replace("'",'"')
import json
data_dict = json.loads(data)
print(type(data_dict))
# Out:
# [{'name': 'JAY', 'age': 23, 'address': 'devendernagar'}, {'name': 'vedha', 'age': 21, 'address': 'ameerpet'}]
# <class 'list'>

# %%
import os
import pickle
path=os.path.join("data","customers.csv")
customers= [{"name":"JAY","age":23,"address":"devendernagar"},{"name":"vedha","age":21,"address":"ameerpet"}]
f=open(path,"wb")
pickle.dump(customers,f)
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path,"rb")
data=f.read()
print(data)
print(type(data))
# Out:
# b'\x80\x03]q\x00(}q\x01(X\x04\x00\x00\x00nameq\x02X\x03\x00\x00\x00JAYq\x03X\x03\x00\x00\x00ageq\x04K\x17X\x07\x00\x00\x00addressq\x05X\r\x00\x00\x00devendernagarq\x06u}q\x07(h\x02X\x05\x00\x00\x00vedhaq\x08h\x04K\x15h\x05X\x08\x00\x00\x00ameerpetq\tue.'
# <class 'bytes'>

# %%
import os
import pickle
path=os.path.join("data","customers.csv")
f=open(path,"rb")
data=pickle.load(f)
print(data)
print(type(data))
# Out:
# [{'name': 'JAY', 'age': 23, 'address': 'devendernagar'}, {'name': 'vedha', 'age': 21, 'address': 'ameerpet'}]
# <class 'list'>

# %%
# work with json files and yaml files.
# Read 30GB file

# %%
f=open("fun_mem3.jpg","rb")
data = f.read()
f.close()
f=open("bigfile.jpg","wb")
for i in range(10):
    f.write(data)
    f.flush()
f.close()

# %%
f=open("bigfile.jpg","rb") # bigfile.jpg size should be 30GB
data=f.read()

# %%
import os
import random
path=os.path.join("data","customers.csv")
f=open(path,"w")
f.write("name,dep,age,sal\n")
names=["vishal","samba","jay","vedha","Mounika","Jaganath"]
ages=[23,25,44,46,26,27]
sals=range(30000,100000)
depts=["testing","development","management","design"]
random.choice(names)
for i in range(100):
    row="%s,%s,%s,%s\n"%(random.choice(names),random.choice(depts),random.choice(ages),random.choice(sals))
    print(row)
    break
# Out:
# vedha,development,23,42636

# %%
import os
import random
path=os.path.join("data","customers.csv")
f=open(path,"w")
f.write("name,dep,age,sal\n")
names=["vishal","samba","jay","vedha","Mounika","Jaganath"]
ages=[23,25,44,46,26,27]
sals=range(30000,100000)
depts=["testing","development","management","design"]
random.choice(names)
for i in range(100):
    row="%s,%s,%s,%s\n"%(random.choice(names),random.choice(depts),random.choice(ages),random.choice(sals))
    f.write(row)
    f.flush()
f.close()

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path)
data=f.read()
print(data)
# Out:
# name,dep,age,sal
# Mounika,design,46,51304
# vishal,testing,27,31153
# samba,testing,25,51365
# jay,development,44,70840
# vedha,management,27,66481
# jay,management,27,72143
# vedha,design,27,44485
# Mounika,design,46,49136
# jay,management,46,77027
# Mounika,management,26,98353
# vedha,development,44,43977
# jay,design,25,70657
# Mounika,design,27,41647
# samba,design,27,90515
# vedha,management,46,79803
# jay,development,27,77828
# vedha,design,23,50702
# vedha,design,46,42289
# vishal,management,46,42530
# jay,development,26,32493
# samba,testing,23,98347
# Mounika,design,27,82262
# samba,development,46,76551
# jay,management,46,90334
# samba,testing,26,99147
# vishal,management,44,42963
# Mounika,testing,46,65469
# jay,management,27,49879
# samba,management,25,58382
# Mounika,design,44,78935
# jay,testing,26,43336
# Mounika,management,25,68970
# samba,design,23,74536
# vedha,testing,44,34984
# vishal,testing,26,42833
# vishal,management,26,76541
# vedha,management,25,52332
# samba,management,25,48229
# vedha,design,23,90271
# vedha,testing,27,73327
# vedha,development,23,91241
# vedha,development,25,56043
# vedha,management,26,71456
# vedha,testing,26,30807
# jay,design,46,62123
# Mounika,testing,23,91989
# samba,testing,23,49440
# Jaganath,design,46,83983
# jay,design,44,72507
# Jaganath,management,26,94831
# Mounika,management,44,49824
# Mounika,management,26,48182
# vedha,management,26,64291
# Mounika,management,25,32972
# jay,management,27,63536
# vishal,management,44,75052
# samba,management,44,82610
# jay,management,46,51869
# jay,management,26,83549
# vishal,development,23,68565
# samba,testing,44,97905
# vedha,management,25,32507
# jay,design,26,88336
# vishal,management,44,55454
# vedha,management,27,94849
# Jaganath,development,26,40569
# jay,management,44,67436
# Mounika,testing,26,52077
# samba,design,27,84398
# Mounika,development,44,61237
# Mounika,development,27,89273
# samba,testing,44,74256
# vishal,development,46,98595
# Jaganath,management,23,44197
# Mounika,testing,44,41599
# Mounika,management,23,36490
# vishal,management,46,50174
# vishal,management,23,46582
# samba,management,26,44460
# Jaganath,management,46,62563
# vishal,testing,23,38614
# samba,testing,27,82289
# vishal,design,46,92759
# jay,design,44,58029
# vedha,testing,23,84535
# vedha,management,25,75086
# jay,testing,23,40005
# samba,development,27,43240
# jay,design,27,38527
# Mounika,testing,27,68207
# vishal,development,26,45553
# vishal,testing,46,36754
# vishal,development,27,33352
# Jaganath,development,46,96650
# jay,development,44,86215
# Jaganath,management,25,66233
# jay,design,25,82356
# jay,design,27,64626
# jay,design,23,38860
# samba,testing,25,32692

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path)
data=f.read(100)
print(data)
data=f.read(100)
print("*"*20)
print(data)
# Out:
# name,dep,age,sal
# Mounika,design,46,51304
# vishal,testing,27,31153
# samba,testing,25,51365
# jay,developm
# ********************
# ent,44,70840
# vedha,management,27,66481
# jay,management,27,72143
# vedha,design,27,44485
# Mounika,design,

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path)
data=f.read()
print(data)
data=f.read()
print("*"*20)
print(data)
# Out:
# name,dep,age,sal
# Mounika,design,46,51304
# vishal,testing,27,31153
# samba,testing,25,51365
# jay,development,44,70840
# vedha,management,27,66481
# jay,management,27,72143
# vedha,design,27,44485
# Mounika,design,46,49136
# jay,management,46,77027
# Mounika,management,26,98353
# vedha,development,44,43977
# jay,design,25,70657
# Mounika,design,27,41647
# samba,design,27,90515
# vedha,management,46,79803
# jay,development,27,77828
# vedha,design,23,50702
# vedha,design,46,42289
# vishal,management,46,42530
# jay,development,26,32493
# samba,testing,23,98347
# Mounika,design,27,82262
# samba,development,46,76551
# jay,management,46,90334
# samba,testing,26,99147
# vishal,management,44,42963
# Mounika,testing,46,65469
# jay,management,27,49879
# samba,management,25,58382
# Mounika,design,44,78935
# jay,testing,26,43336
# Mounika,management,25,68970
# samba,design,23,74536
# vedha,testing,44,34984
# vishal,testing,26,42833
# vishal,management,26,76541
# vedha,management,25,52332
# samba,management,25,48229
# vedha,design,23,90271
# vedha,testing,27,73327
# vedha,development,23,91241
# vedha,development,25,56043
# vedha,management,26,71456
# vedha,testing,26,30807
# jay,design,46,62123
# Mounika,testing,23,91989
# samba,testing,23,49440
# Jaganath,design,46,83983
# jay,design,44,72507
# Jaganath,management,26,94831
# Mounika,management,44,49824
# Mounika,management,26,48182
# vedha,management,26,64291
# Mounika,management,25,32972
# jay,management,27,63536
# vishal,management,44,75052
# samba,management,44,82610
# jay,management,46,51869
# jay,management,26,83549
# vishal,development,23,68565
# samba,testing,44,97905
# vedha,management,25,32507
# jay,design,26,88336
# vishal,management,44,55454
# vedha,management,27,94849
# Jaganath,development,26,40569
# jay,management,44,67436
# Mounika,testing,26,52077
# samba,design,27,84398
# Mounika,development,44,61237
# Mounika,development,27,89273
# samba,testing,44,74256
# vishal,development,46,98595
# Jaganath,management,23,44197
# Mounika,testing,44,41599
# Mounika,management,23,36490
# vishal,management,46,50174
# vishal,management,23,46582
# samba,management,26,44460
# Jaganath,management,46,62563
# vishal,testing,23,38614
# samba,testing,27,82289
# vishal,design,46,92759
# jay,design,44,58029
# vedha,testing,23,84535
# vedha,management,25,75086
# jay,testing,23,40005
# samba,development,27,43240
# jay,design,27,38527
# Mounika,testing,27,68207
# vishal,development,26,45553
# vishal,testing,46,36754
# vishal,development,27,33352
# Jaganath,development,46,96650
# jay,development,44,86215
# Jaganath,management,25,66233
# jay,design,25,82356
# jay,design,27,64626
# jay,design,23,38860
# samba,testing,25,32692
#
# ********************

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path)
data=f.read(100)
while data:
    print("*"*20)
    data = f.read(100)
    print(data)
print("read completed")
# Out:
# ********************
# ent,44,70840
# vedha,management,27,66481
# jay,management,27,72143
# vedha,design,27,44485
# Mounika,design,
# ********************
# 46,49136
# jay,management,46,77027
# Mounika,management,26,98353
# vedha,development,44,43977
# jay,design,2
# ********************
# 5,70657
# Mounika,design,27,41647
# samba,design,27,90515
# vedha,management,46,79803
# jay,development,27,7
# ********************
# 7828
# vedha,design,23,50702
# vedha,design,46,42289
# vishal,management,46,42530
# jay,development,26,32493
# ********************
#
# samba,testing,23,98347
# Mounika,design,27,82262
# samba,development,46,76551
# jay,management,46,90334
# s
# ********************
# amba,testing,26,99147
# vishal,management,44,42963
# Mounika,testing,46,65469
# jay,management,27,49879
# sa
# ********************
# mba,management,25,58382
# Mounika,design,44,78935
# jay,testing,26,43336
# Mounika,management,25,68970
# sam
# ********************
# ba,design,23,74536
# vedha,testing,44,34984
# vishal,testing,26,42833
# vishal,management,26,76541
# vedha,m
# ********************
# anagement,25,52332
# samba,management,25,48229
# vedha,design,23,90271
# vedha,testing,27,73327
# vedha,deve
# ********************
# lopment,23,91241
# vedha,development,25,56043
# vedha,management,26,71456
# vedha,testing,26,30807
# jay,des
# ********************
# ign,46,62123
# Mounika,testing,23,91989
# samba,testing,23,49440
# Jaganath,design,46,83983
# jay,design,44,
# ********************
# 72507
# Jaganath,management,26,94831
# Mounika,management,44,49824
# Mounika,management,26,48182
# vedha,man
# ********************
# agement,26,64291
# Mounika,management,25,32972
# jay,management,27,63536
# vishal,management,44,75052
# samb
# ********************
# a,management,44,82610
# jay,management,46,51869
# jay,management,26,83549
# vishal,development,23,68565
# sa
# ********************
# mba,testing,44,97905
# vedha,management,25,32507
# jay,design,26,88336
# vishal,management,44,55454
# vedha,
# ********************
# management,27,94849
# Jaganath,development,26,40569
# jay,management,44,67436
# Mounika,testing,26,52077
# s
# ********************
# amba,design,27,84398
# Mounika,development,44,61237
# Mounika,development,27,89273
# samba,testing,44,7425
# ********************
# 6
# vishal,development,46,98595
# Jaganath,management,23,44197
# Mounika,testing,44,41599
# Mounika,manageme
# ********************
# nt,23,36490
# vishal,management,46,50174
# vishal,management,23,46582
# samba,management,26,44460
# Jaganath
# ********************
# ,management,46,62563
# vishal,testing,23,38614
# samba,testing,27,82289
# vishal,design,46,92759
# jay,desig
# ********************
# n,44,58029
# vedha,testing,23,84535
# vedha,management,25,75086
# jay,testing,23,40005
# samba,development,2
# ********************
# 7,43240
# jay,design,27,38527
# Mounika,testing,27,68207
# vishal,development,26,45553
# vishal,testing,46,3
# ********************
# 6754
# vishal,development,27,33352
# Jaganath,development,46,96650
# jay,development,44,86215
# Jaganath,man
# ********************
# agement,25,66233
# jay,design,25,82356
# jay,design,27,64626
# jay,design,23,38860
# samba,testing,25,32692
#
# ********************
#
# read completed

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path)
data=f.readline()
while data:
    print("*"*20)
    data = f.readline()
    print(data)
print("read completed")
# Out:
# ********************
# Mounika,design,46,51304
#
# ********************
# vishal,testing,27,31153
#
# ********************
# samba,testing,25,51365
#
# ********************
# jay,development,44,70840
#
# ********************
# vedha,management,27,66481
#
# ********************
# jay,management,27,72143
#
# ********************
# vedha,design,27,44485
#
# ********************
# Mounika,design,46,49136
#
# ********************
# jay,management,46,77027
#
# ********************
# Mounika,management,26,98353
#
# ********************
# vedha,development,44,43977
#
# ********************
# jay,design,25,70657
#
# ********************
# Mounika,design,27,41647
#
# ********************
# samba,design,27,90515
#
# ********************
# vedha,management,46,79803
#
# ********************
# jay,development,27,77828
#
# ********************
# vedha,design,23,50702
#
# ********************
# vedha,design,46,42289
#
# ********************
# vishal,management,46,42530
#
# ********************
# jay,development,26,32493
#
# ********************
# samba,testing,23,98347
#
# ********************
# Mounika,design,27,82262
#
# ********************
# samba,development,46,76551
#
# ********************
# jay,management,46,90334
#
# ********************
# samba,testing,26,99147
#
# ********************
# vishal,management,44,42963
#
# ********************
# Mounika,testing,46,65469
#
# ********************
# jay,management,27,49879
#
# ********************
# samba,management,25,58382
#
# ********************
# Mounika,design,44,78935
#
# ********************
# jay,testing,26,43336
#
# ********************
# Mounika,management,25,68970
#
# ********************
# samba,design,23,74536
#
# ********************
# vedha,testing,44,34984
#
# ********************
# vishal,testing,26,42833
#
# ********************
# vishal,management,26,76541
#
# ********************
# vedha,management,25,52332
#
# ********************
# samba,management,25,48229
#
# ********************
# vedha,design,23,90271
#
# ********************
# vedha,testing,27,73327
#
# ********************
# vedha,development,23,91241
#
# ********************
# vedha,development,25,56043
#
# ********************
# vedha,management,26,71456
#
# ********************
# vedha,testing,26,30807
#
# ********************
# jay,design,46,62123
#
# ********************
# Mounika,testing,23,91989
#
# ********************
# samba,testing,23,49440
#
# ********************
# Jaganath,design,46,83983
#
# ********************
# jay,design,44,72507
#
# ********************
# Jaganath,management,26,94831
#
# ********************
# Mounika,management,44,49824
#
# ********************
# Mounika,management,26,48182
#
# ********************
# vedha,management,26,64291
#
# ********************
# Mounika,management,25,32972
#
# ********************
# jay,management,27,63536
#
# ********************
# vishal,management,44,75052
#
# ********************
# samba,management,44,82610
#
# ********************
# jay,management,46,51869
#
# ********************
# jay,management,26,83549
#
# ********************
# vishal,development,23,68565
#
# ********************
# samba,testing,44,97905
#
# ********************
# vedha,management,25,32507
#
# ********************
# jay,design,26,88336
#
# ********************
# vishal,management,44,55454
#
# ********************
# vedha,management,27,94849
#
# ********************
# Jaganath,development,26,40569
#
# ********************
# jay,management,44,67436
#
# ********************
# Mounika,testing,26,52077
#
# ********************
# samba,design,27,84398
#
# ********************
# Mounika,development,44,61237
#
# ********************
# Mounika,development,27,89273
#
# ********************
# samba,testing,44,74256
#
# ********************
# vishal,development,46,98595
#
# ********************
# Jaganath,management,23,44197
#
# ********************
# Mounika,testing,44,41599
#
# ********************
# Mounika,management,23,36490
#
# ********************
# vishal,management,46,50174
#
# ********************
# vishal,management,23,46582
#
# ********************
# samba,management,26,44460
#
# ********************
# Jaganath,management,46,62563
#
# ********************
# vishal,testing,23,38614
#
# ********************
# samba,testing,27,82289
#
# ********************
# vishal,design,46,92759
#
# ********************
# jay,design,44,58029
#
# ********************
# vedha,testing,23,84535
#
# ********************
# vedha,management,25,75086
#
# ********************
# jay,testing,23,40005
#
# ********************
# samba,development,27,43240
#
# ********************
# jay,design,27,38527
#
# ********************
# Mounika,testing,27,68207
#
# ********************
# vishal,development,26,45553
#
# ********************
# vishal,testing,46,36754
#
# ********************
# vishal,development,27,33352
#
# ********************
# Jaganath,development,46,96650
#
# ********************
# jay,development,44,86215
#
# ********************
# Jaganath,management,25,66233
#
# ********************
# jay,design,25,82356
#
# ********************
# jay,design,27,64626
#
# ********************
# jay,design,23,38860
#
# ********************
# samba,testing,25,32692
#
# ********************
#
# read completed

# %%
import os
path=os.path.join("data","customers.csv")
f=open(path)
for row in f:
    print("*"*20)
    print(row)
print("read completed")
# Out:
# ********************
# name,dep,age,sal
#
# ********************
# Mounika,design,46,51304
#
# ********************
# vishal,testing,27,31153
#
# ********************
# samba,testing,25,51365
#
# ********************
# jay,development,44,70840
#
# ********************
# vedha,management,27,66481
#
# ********************
# jay,management,27,72143
#
# ********************
# vedha,design,27,44485
#
# ********************
# Mounika,design,46,49136
#
# ********************
# jay,management,46,77027
#
# ********************
# Mounika,management,26,98353
#
# ********************
# vedha,development,44,43977
#
# ********************
# jay,design,25,70657
#
# ********************
# Mounika,design,27,41647
#
# ********************
# samba,design,27,90515
#
# ********************
# vedha,management,46,79803
#
# ********************
# jay,development,27,77828
#
# ********************
# vedha,design,23,50702
#
# ********************
# vedha,design,46,42289
#
# ********************
# vishal,management,46,42530
#
# ********************
# jay,development,26,32493
#
# ********************
# samba,testing,23,98347
#
# ********************
# Mounika,design,27,82262
#
# ********************
# samba,development,46,76551
#
# ********************
# jay,management,46,90334
#
# ********************
# samba,testing,26,99147
#
# ********************
# vishal,management,44,42963
#
# ********************
# Mounika,testing,46,65469
#
# ********************
# jay,management,27,49879
#
# ********************
# samba,management,25,58382
#
# ********************
# Mounika,design,44,78935
#
# ********************
# jay,testing,26,43336
#
# ********************
# Mounika,management,25,68970
#
# ********************
# samba,design,23,74536
#
# ********************
# vedha,testing,44,34984
#
# ********************
# vishal,testing,26,42833
#
# ********************
# vishal,management,26,76541
#
# ********************
# vedha,management,25,52332
#
# ********************
# samba,management,25,48229
#
# ********************
# vedha,design,23,90271
#
# ********************
# vedha,testing,27,73327
#
# ********************
# vedha,development,23,91241
#
# ********************
# vedha,development,25,56043
#
# ********************
# vedha,management,26,71456
#
# ********************
# vedha,testing,26,30807
#
# ********************
# jay,design,46,62123
#
# ********************
# Mounika,testing,23,91989
#
# ********************
# samba,testing,23,49440
#
# ********************
# Jaganath,design,46,83983
#
# ********************
# jay,design,44,72507
#
# ********************
# Jaganath,management,26,94831
#
# ********************
# Mounika,management,44,49824
#
# ********************
# Mounika,management,26,48182
#
# ********************
# vedha,management,26,64291
#
# ********************
# Mounika,management,25,32972
#
# ********************
# jay,management,27,63536
#
# ********************
# vishal,management,44,75052
#
# ********************
# samba,management,44,82610
#
# ********************
# jay,management,46,51869
#
# ********************
# jay,management,26,83549
#
# ********************
# vishal,development,23,68565
#
# ********************
# samba,testing,44,97905
#
# ********************
# vedha,management,25,32507
#
# ********************
# jay,design,26,88336
#
# ********************
# vishal,management,44,55454
#
# ********************
# vedha,management,27,94849
#
# ********************
# Jaganath,development,26,40569
#
# ********************
# jay,management,44,67436
#
# ********************
# Mounika,testing,26,52077
#
# ********************
# samba,design,27,84398
#
# ********************
# Mounika,development,44,61237
#
# ********************
# Mounika,development,27,89273
#
# ********************
# samba,testing,44,74256
#
# ********************
# vishal,development,46,98595
#
# ********************
# Jaganath,management,23,44197
#
# ********************
# Mounika,testing,44,41599
#
# ********************
# Mounika,management,23,36490
#
# ********************
# vishal,management,46,50174
#
# ********************
# vishal,management,23,46582
#
# ********************
# samba,management,26,44460
#
# ********************
# Jaganath,management,46,62563
#
# ********************
# vishal,testing,23,38614
#
# ********************
# samba,testing,27,82289
#
# ********************
# vishal,design,46,92759
#
# ********************
# jay,design,44,58029
#
# ********************
# vedha,testing,23,84535
#
# ********************
# vedha,management,25,75086
#
# ********************
# jay,testing,23,40005
#
# ********************
# samba,development,27,43240
#
# ********************
# jay,design,27,38527
#
# ********************
# Mounika,testing,27,68207
#
# ********************
# vishal,development,26,45553
#
# ********************
# vishal,testing,46,36754
#
# ********************
# vishal,development,27,33352
#
# ********************
# Jaganath,development,46,96650
#
# ********************
# jay,development,44,86215
#
# ********************
# Jaganath,management,25,66233
#
# ********************
# jay,design,25,82356
#
# ********************
# jay,design,27,64626
#
# ********************
# jay,design,23,38860
#
# ********************
# samba,testing,25,32692
#
# read completed

# %%
import os
import pandas as pd
path=os.path.join("data","customers.csv")
data=pd.read_csv(path)
print(data)
# Out:
#         name          dep  age    sal
# 0    Mounika       design   46  51304
# 1     vishal      testing   27  31153
# 2      samba      testing   25  51365
# 3        jay  development   44  70840
# 4      vedha   management   27  66481
# 5        jay   management   27  72143
# 6      vedha       design   27  44485
# 7    Mounika       design   46  49136
# 8        jay   management   46  77027
# 9    Mounika   management   26  98353
# 10     vedha  development   44  43977
# 11       jay       design   25  70657
# 12   Mounika       design   27  41647
# 13     samba       design   27  90515
# 14     vedha   management   46  79803
# 15       jay  development   27  77828
# 16     vedha       design   23  50702
# 17     vedha       design   46  42289
# 18    vishal   management   46  42530
# 19       jay  development   26  32493
# 20     samba      testing   23  98347
# 21   Mounika       design   27  82262
# 22     samba  development   46  76551
# 23       jay   management   46  90334
# 24     samba      testing   26  99147
# 25    vishal   management   44  42963
# 26   Mounika      testing   46  65469
# 27       jay   management   27  49879
# 28     samba   management   25  58382
# 29   Mounika       design   44  78935
# ..       ...          ...  ...    ...
# 70   Mounika  development   27  89273
# 71     samba      testing   44  74256
# 72    vishal  development   46  98595
# 73  Jaganath   management   23  44197
# 74   Mounika      testing   44  41599
# 75   Mounika   management   23  36490
# 76    vishal   management   46  50174
# 77    vishal   management   23  46582
# 78     samba   management   26  44460
# 79  Jaganath   management   46  62563
# 80    vishal      testing   23  38614
# 81     samba      testing   27  82289
# 82    vishal       design   46  92759
# 83       jay       design   44  58029
# 84     vedha      testing   23  84535
# 85     vedha   management   25  75086
# 86       jay      testing   23  40005
# 87     samba  development   27  43240
# 88       jay       design   27  38527
# 89   Mounika      testing   27  68207
# 90    vishal  development   26  45553
# 91    vishal      testing   46  36754
# 92    vishal  development   27  33352
# 93  Jaganath  development   46  96650
# 94       jay  development   44  86215
# 95  Jaganath   management   25  66233
# 96       jay       design   25  82356
# 97       jay       design   27  64626
# 98       jay       design   23  38860
# 99     samba      testing   25  32692
#
# [100 rows x 4 columns]

# %%
data.plot()

# %%
import matplotlib.pyplot as plt

# %%
data.plot()
plt.show()

# %%
data.plot(x="age",y="sal")
plt.show()

# %%
data.columns
# Out:
# Index(['name', 'dep', 'age', 'sal'], dtype='object')

# %%
data.sort_values(by="sal", inplace=True)

# %%
data.head()
# Out:
#       name          dep  age    sal
# 43   vedha      testing   26  30807
# 1   vishal      testing   27  31153
# 19     jay  development   26  32493
# 61   vedha   management   25  32507
# 99   samba      testing   25  32692

# %%
data[data["age"]==27]
# Out:
#        name          dep  age    sal
# 1    vishal      testing   27  31153
# 92   vishal  development   27  33352
# 88      jay       design   27  38527
# 12  Mounika       design   27  41647
# 87    samba  development   27  43240
# 6     vedha       design   27  44485
# 27      jay   management   27  49879
# 54      jay   management   27  63536
# 97      jay       design   27  64626
# 4     vedha   management   27  66481
# 89  Mounika      testing   27  68207
# 5       jay   management   27  72143
# 39    vedha      testing   27  73327
# 15      jay  development   27  77828
# 21  Mounika       design   27  82262
# 81    samba      testing   27  82289
# 68    samba       design   27  84398
# 70  Mounika  development   27  89273
# 13    samba       design   27  90515
# 64    vedha   management   27  94849

# %%
data[data["age"]==27].mean()
# Out:
# name                         0j
# dep        0.35000000000000003j
# age                     (27+0j)
# sal     (64600.850000000006+0j)
# dtype: complex128

# %%
data.groupby("age").mean()
# Out:
#               sal
# age
# 23   62958.266667
# 25   55986.461538
# 26   62165.529412
# 27   64600.850000
# 44   64342.529412
# 46   67217.388889

# %%
data.groupby("age").mean().plot()
plt.show()
